# %% [markdown]
# # Lab 1: Information Retrieval

# %% [markdown]
# __Students:__

# %% [markdown]
# ### Crawling

# %% [markdown]
# a) Get the webpage content by using functions in
# __[urllib module](https://docs.python.org/3/library/urllib.html#module-urllib)__.
#
# Other libraries are also fine to achieve the crawling.
#
# e.g. scrapy, beautifulsoup...
#
# We manually go went through some categories and added to an array which we run through and retrieved all HTML

# %%
import urllib.request

urls = [
    'https://play.google.com/store/apps?hl=en',
    'https://play.google.com/store/apps/category/GAME?hl=en',
    'https://play.google.com/store/apps/category/ART_AND_DESIGN?hl=en',
    'https://play.google.com/store/apps/category/BUSINESS?hl=en',
    'https://play.google.com/store/apps/category/BEAUTY?hl=en',
    'https://play.google.com/store/apps/category/COMICS?hl=en',
    'https://play.google.com/store/apps/category/COMMUNICATION?hl=en',
    'https://play.google.com/store/apps/category/DATING?hl=en',
    'https://play.google.com/store/apps/category/EDUCATION?hl=en',
    'https://play.google.com/store/apps/category/ENTERTAINMENT?hl=en',
    'https://play.google.com/store/apps/category/EVENTS?hl=en',
    'https://play.google.com/store/apps/category/FINANCE?hl=en',
    'https://play.google.com/store/apps/category/FOOD_AND_DRINK?hl=en',
    'https://play.google.com/store/apps/category/HEALTH_AND_FITNESS?hl=en',
    'https://play.google.com/store/apps/category/HOUSE_AND_HOME?hl=en',
    'https://play.google.com/store/apps/category/LIBRARIES_AND_DEMO?hl=en',
    'https://play.google.com/store/apps/category/LIFESTYLE?hl=en',
    'https://play.google.com/store/apps/category/MAPS_AND_NAVIGATION?hl=en',
    'https://play.google.com/store/apps/category/MEDICAL?hl=en',
    'https://play.google.com/store/apps/category/MUSIC_AND_AUDIO?hl=en',
    'https://play.google.com/store/apps/category/NEWS_AND_MAGAZINES?hl=en',
    'https://play.google.com/store/apps/category/PARENTING?hl=en',
    'https://play.google.com/store/apps/category/PERSONALIZATION?hl=en',
    'https://play.google.com/store/apps/category/PHOTOGRAPHY?hl=en',
    'https://play.google.com/store/apps/category/PRODUCTIVITY?hl=en',
    'https://play.google.com/store/apps/category/SHOPPING?hl=en',
    'https://play.google.com/store/apps/category/SOCIAL?hl=en',
    'https://play.google.com/store/apps/top?hl=en',
    'https://play.google.com/store/apps/collection/topselling_free?hl=en',
    'https://play.google.com/store/apps/new?hl=en',
    'https://play.google.com/store/apps/collection/topselling_new_free?hl=en',
    'https://play.google.com/store/apps/category/GAME/collection/topselling_new_paid?hl=en',
    'https://play.google.com/store/apps/category/FAMILY?hl=en',
    'https://play.google.com/store/apps/collection/topselling_paid?hl=en',
    'https://play.google.com/store/apps/collection/topgrossing?hl=en'
]

sources = []

for url in urls:
    try:
        x = urllib.request.urlopen(url).read().decode('utf-8')
        sources.append(x)
    except:
        print('error on', url)

# %% [markdown]
# Just counting and checking that we are not getting any weird data back

# %%
print(len(sources))
for s in sources:
    print(len(s))
# Out:
# 35
# 391701
# 377364
# 103892
# 102661
# 102704
# 102242
# 102788
# 265346
# 102785
# 102741
# 102653
# 101905
# 103286
# 122994
# 102841
# 104626
# 103440
# 105611
# 372648
# 103507
# 103545
# 103049
# 103170
# 103207
# 103248
# 102624
# 102498
# 562818
# 255716
# 404148
# 261631
# 165497
# 380580
# 316443
# 257450

# %% [markdown]
# b) Get app url by regular expression using functions from __[re module](https://docs.python.org/3/library/re.html?highlight=re#module-re)__.
#
# A useful online regular expression check.
# __[Check your regular expression first](https://regex101.com)__.
#
# We go though all the HTML we retrieved earlier and extract app urls with the given regex expression, getting all unique app urls and collecting them into a larger set.

# %%
import re
appreg = r'href=\"(/store/apps/details.*?)\"'
appre = re.compile(appreg)

all_app_urls = []
for s in sources:
    app_url_list = re.findall(appre,s)
    app_url_list = list(set(app_url_list))
    all_app_urls += app_url_list
    #print(len(app_url_list))
    #print(app_url_list)
    
all_app_urls = list(set(all_app_urls))
print(len(all_app_urls))
print(all_app_urls)
# Out:
# 767
# ['/store/apps/details?id=vn.vtv.vtvgotv', '/store/apps/details?id=com.rockstargames.gtasa', '/store/apps/details?id=net.dinglisch.android.taskerm', '/store/apps/details?id=dynnsoft.strangersmeet', '/store/apps/details?id=com.whatsapp', '/store/apps/details?id=com.learnarabic', '/store/apps/details?id=com.gamesbynoe.intotheabyss', '/store/apps/details?id=com.devolver.reignsGot', '/store/apps/details?id=com.oramdic.dictionnaire.francais', '/store/apps/details?id=com.funplus.kingofavalon', '/store/apps/details?id=twiceme.myiceinfo.org', '/store/apps/details?id=com.cocoplay.erpetvet', '/store/apps/details?id=com.facebook.lite', '/store/apps/details?id=com.ilikeyou', '/store/apps/details?id=org.siop.siop2018', '/store/apps/details?id=net.daylio', '/store/apps/details?id=com.doro.apps.mydoro.senior', '/store/apps/details?id=com.doodlejoy.studio.kidsdoojoy', '/store/apps/details?id=com.edujoy.Baby_puzzles', '/store/apps/details?id=io.voodoo.paper2', '/store/apps/details?id=com.crowdstar.covetHome', '/store/apps/details?id=com.king.farmheroessaga', '/store/apps/details?id=com.abtnprojects.ambatana', '/store/apps/details?id=se.filimundus.pippivvkhd', '/store/apps/details?id=canadianmeet.dating.chatsingles.friends', '/store/apps/details?id=com.soomapps.screenmirroring', '/store/apps/details?id=com.rvappstudios.abc_kids_toddler_tracing_phonics', '/store/apps/details?id=com.firsttouchgames.story', '/store/apps/details?id=com.jaumo.prime', '/store/apps/details?id=org.scratchjr.android', '/store/apps/details?id=com.outfit7.talkingtomgoldrun', '/store/apps/details?id=com.combineinc.streetracing.driftthreeD', '/store/apps/details?id=com.nintendo.zaba', '/store/apps/details?id=com.dingogames.tastyplanet4', '/store/apps/details?id=ua.rabota.app', '/store/apps/details?id=se.evidensia.veterinar.video', '/store/apps/details?id=com.nintendo.zara', '/store/apps/details?id=com.samsung.knox.securefolder', '/store/apps/details?id=com.lguplus.navi', '/store/apps/details?id=com.logame.jumprelax', '/store/apps/details?id=com.waze', '/store/apps/details?id=com.ansangha.drdriving', '/store/apps/details?id=se.teoriappar.takorkort', '/store/apps/details?id=com.clean.security.memory.booster.battery', '/store/apps/details?id=com.monashuniversity.fodmap', '/store/apps/details?id=com.android.chrome', '/store/apps/details?id=com.lezhin.comics', '/store/apps/details?id=com.catfishanimationstudio.MuscularSystemLite', '/store/apps/details?id=com.magmon.cartooncraft', '/store/apps/details?id=com.gameloft.android.ANMP.GloftPOHM', '/store/apps/details?id=com.wb.goog.got.conquest', '/store/apps/details?id=com.daysofwonder.tt.android', '/store/apps/details?id=com.nianticlabs.pokemongo', '/store/apps/details?id=com.sevelina.icywedding', '/store/apps/details?id=com.sgg.hoht', '/store/apps/details?id=com.vethem', '/store/apps/details?id=yio.tro.bleentoro_pro', '/store/apps/details?id=com.TripleTopping.TTSpitkiss', '/store/apps/details?id=com.teamspeak.ts3client', '/store/apps/details?id=com.speedboat.jetski.racing.simulator', '/store/apps/details?id=com.vmb.lichvannien.new2018', '/store/apps/details?id=com.lenovo.anyshare.gps', '/store/apps/details?id=com.plarium.vikings', '/store/apps/details?id=persian.facemasks', '/store/apps/details?id=net.mugcat.ranchat', '/store/apps/details?id=com.zynga.livepoker', '/store/apps/details?id=com.cmplay.bricksnballs', '/store/apps/details?id=com.minimo.miniracingadventures', '/store/apps/details?id=com.netvariant.civilaffairs', '/store/apps/details?id=com.ubisoft.assassinscreed.identity', '/store/apps/details?id=net.cleverbit.VegeFruits', '/store/apps/details?id=com.outfit7.mytalkingangelafree', '/store/apps/details?id=com.fasho.gravity', '/store/apps/details?id=com.indymobileapp.document.scanner', '/store/apps/details?id=com.instagram.android', '/store/apps/details?id=com.mason.wooplus', '/store/apps/details?id=com.king.candycrushsodasaga', '/store/apps/details?id=com.puzzlegame.puzzledom', '/store/apps/details?id=com.gameloft.android.AN ...

# %% [markdown]
# This approach just yields ~750 unique app urls. We do another round using those app urls to find similar apps in order to go above 1000 apps.

# %%
second_round_urls = []

for url in all_app_urls[1:200]:
    try:
        x = urllib.request.urlopen('https://play.google.com/' + url).read().decode('utf-8')
        app_url_list = re.findall(appre,x)
        app_url_list = list(set(app_url_list))
        second_round_urls += app_url_list
    except:
        print('error on', url)
        
second_round_urls = list(set(second_round_urls))
print(len(second_round_urls))
print(second_round_urls)
# Out:
# 1128
# ['/store/apps/details?id=com.oramdic.dictionary.portuguese.english', '/store/apps/details?id=com.dramaton.dramaton', '/store/apps/details?id=com.ubisoft.accovenant', '/store/apps/details?id=com.fingersoft.makemore', '/store/apps/details?id=com.fatcat.SuperstarMakeupProm', '/store/apps/details?id=com.instantbits.cast.webvideo', '/store/apps/details?id=com.amanotes.beathopper', '/store/apps/details?id=com.discord', '/store/apps/details?id=com.whatsapp', '/store/apps/details?id=com.ubisoft.grwhq', '/store/apps/details?id=com.sphero.sprk', '/store/apps/details?id=com.monsters.vs.water.duel', '/store/apps/details?id=com.kids.free.audiobook.classical.music.for.baby', '/store/apps/details?id=com.relaxing.musicsounds', '/store/apps/details?id=com.ductho.baomoii', '/store/apps/details?id=com.devolver.reignsGot', '/store/apps/details?id=call.recorder.automatic.acr', '/store/apps/details?id=ua.prom.b2c', '/store/apps/details?id=com.funplus.kingofavalon', '/store/apps/details?id=ma.safe.cooking', '/store/apps/details?id=com.heavens_above.viewer', '/store/apps/details?id=dsa.father.day.photo.frame', '/store/apps/details?id=com.bimiboo.adventure', '/store/apps/details?id=com.fourtechnologies.mynetdiary.ad', '/store/apps/details?id=se.filimundus.pi2', '/store/apps/details?id=com.facebook.lite', '/store/apps/details?id=com.acidcousins.fdunk', '/store/apps/details?id=air.com.RustyLake.RustyLakeParadise', '/store/apps/details?id=media.music.mp3player.musicplayer', '/store/apps/details?id=com.crescentmoongames.skyfish', '/store/apps/details?id=com.filter.forSnapchat.photo.artCollage', '/store/apps/details?id=com.receita.de.pastels', '/store/apps/details?id=com.goodcatchgames.simonscatrunner', '/store/apps/details?id=io.voodoo.paper2', '/store/apps/details?id=com.turbochilli.rollingsky', '/store/apps/details?id=com.herocraft.game.free.montezuma2', '/store/apps/details?id=com.kauf.princesssalonmakeupfun3d', '/store/apps/details?id=com.glow.android.eve', '/store/apps/details?id=com.auxbrain.egginc', '/store/apps/details?id=com.king.farmheroessaga', '/store/apps/details?id=se.filimundus.pippivvkhd', '/store/apps/details?id=com.igg.pokerdeluxe', '/store/apps/details?id=com.ea.game.pvzfree_row', '/store/apps/details?id=com.royalapp.loveframes', '/store/apps/details?id=com.playzeit.wordcheese', '/store/apps/details?id=com.seshadri.padmaja.expense', '/store/apps/details?id=com.rvappstudios.abc_kids_toddler_tracing_phonics', '/store/apps/details?id=com.leodesol.games.puzzlecollection', '/store/apps/details?id=com.jaumo.prime', '/store/apps/details?id=gogolook.callgogolook2', '/store/apps/details?id=com.outfit7.talkingtomgoldrun', '/store/apps/details?id=com.waterfall.forest.mountain.waterfallphotoframes', '/store/apps/details?id=com.exelerus.apps.esp', '/store/apps/details?id=com.yinzcam.fa.wol', '/store/apps/details?id=com.fingersoft.hcr2', '/store/apps/details?id=com.village.new.rural.villagephotoframes', '/store/apps/details?id=com.vet2pet.brockvilleanimalhospital1962', '/store/apps/details?id=com.nintendo.zara', '/store/apps/details?id=com.multibrains.taxi.passenger.tirhal', '/store/apps/details?id=com.tvnu.app', '/store/apps/details?id=com.waze', '/store/apps/details?id=com.ansangha.drdriving', '/store/apps/details?id=com.dogs.six', '/store/apps/details?id=com.ccl.howtomakeslime', '/store/apps/details?id=com.lego.ninjago.rideninja', '/store/apps/details?id=se.sfbio.mobile.android', '/store/apps/details?id=com.wavemining.emoji.elite', '/store/apps/details?id=com.discs.citizenscience', '/store/apps/details?id=com.incdev02.med01', '/store/apps/details?id=com.gameloft.android.ANMP.GloftIAHM', '/store/apps/details?id=com.wb.goog.got.conquest', '/store/apps/details?id=com.gameloft.android.ANMP.GloftPOHM', '/store/apps/details?id=com.imangi.templerun', '/store/apps/details?id=com.herocraft.game.free.avalanche', '/store/apps/details?id=com.skt.skaf.OA00026910', '/store/apps/details?id=com.vnpay.bidv', '/store/apps/details?id=com.scee.psxandroid', '/store/ap ...

# %% [markdown]
# Great! That yielded another ~1100 apps. Next, we concatenate that set with the app urls we found earlier.

# %%
final_app_urls = list(set(all_app_urls + second_round_urls))
print(len(final_app_urls))
print(final_app_urls)
# Out:
# 1724
# ['/store/apps/details?id=vn.vtv.vtvgotv', '/store/apps/details?id=com.rockstargames.gtasa', '/store/apps/details?id=com.amanotes.beathopper', '/store/apps/details?id=com.relaxing.musicsounds', '/store/apps/details?id=com.transsion.XOSLauncher', '/store/apps/details?id=com.gamesbynoe.intotheabyss', '/store/apps/details?id=com.heavens_above.viewer', '/store/apps/details?id=dsa.father.day.photo.frame', '/store/apps/details?id=com.cocoplay.erpetvet', '/store/apps/details?id=se.filimundus.pi2', '/store/apps/details?id=com.ilikeyou', '/store/apps/details?id=org.siop.siop2018', '/store/apps/details?id=com.acidcousins.fdunk', '/store/apps/details?id=air.com.RustyLake.RustyLakeParadise', '/store/apps/details?id=com.filter.forSnapchat.photo.artCollage', '/store/apps/details?id=com.turbochilli.rollingsky', '/store/apps/details?id=com.crowdstar.covetHome', '/store/apps/details?id=com.abtnprojects.ambatana', '/store/apps/details?id=se.filimundus.pippivvkhd', '/store/apps/details?id=com.igg.pokerdeluxe', '/store/apps/details?id=com.soomapps.screenmirroring', '/store/apps/details?id=com.waterfall.forest.mountain.waterfallphotoframes', '/store/apps/details?id=com.outfit7.talkingtomgoldrun', '/store/apps/details?id=com.nintendo.zaba', '/store/apps/details?id=com.yinzcam.fa.wol', '/store/apps/details?id=se.evidensia.veterinar.video', '/store/apps/details?id=com.vet2pet.brockvilleanimalhospital1962', '/store/apps/details?id=com.lguplus.navi', '/store/apps/details?id=se.teoriappar.takorkort', '/store/apps/details?id=com.monashuniversity.fodmap', '/store/apps/details?id=com.android.chrome', '/store/apps/details?id=com.catfishanimationstudio.MuscularSystemLite', '/store/apps/details?id=com.vnpay.bidv', '/store/apps/details?id=nl.rabobank.pinpin', '/store/apps/details?id=com.nianticlabs.pokemongo', '/store/apps/details?id=com.sgg.wormwrangler', '/store/apps/details?id=com.sgg.hoht', '/store/apps/details?id=com.joaomgcd.autoinput', '/store/apps/details?id=com.vethem', '/store/apps/details?id=com.giphy.messenger', '/store/apps/details?id=com.amlich.lichviet.lichvannien', '/store/apps/details?id=com.speedboat.jetski.racing.simulator', '/store/apps/details?id=com.rookiestudio.perfectviewer', '/store/apps/details?id=com.flexsolutions.diggi.android', '/store/apps/details?id=com.atari.mobile.goonsquad', '/store/apps/details?id=com.binibambini.MiniLite', '/store/apps/details?id=com.niksoftware.snapseed', '/store/apps/details?id=net.isitlove.cartercorp.colin', '/store/apps/details?id=com.minimo.miniracingadventures', '/store/apps/details?id=com.andromo.dev688676.app712182', '/store/apps/details?id=com.fin.esign', '/store/apps/details?id=com.rockstargames.gtavc', '/store/apps/details?id=com.ushareit.listenit', '/store/apps/details?id=net.pluginmedia.pawpatrolflyer', '/store/apps/details?id=com.itchmedia.tc4', '/store/apps/details?id=ch.threema.app', '/store/apps/details?id=com.allshape.Dropcon', '/store/apps/details?id=com.mason.wooplus', '/store/apps/details?id=com.motorola.motodisplay', '/store/apps/details?id=com.king.petrescuesaga', '/store/apps/details?id=com.disney.disneygif_goo', '/store/apps/details?id=com.revolverolver.fliptrickster', '/store/apps/details?id=se.filimundus.pideluxe', '/store/apps/details?id=se.feomedia.quizkampen.de.lite', '/store/apps/details?id=com.Rain.Teslagrad', '/store/apps/details?id=cool.f3', '/store/apps/details?id=com.skt.tmap.ku', '/store/apps/details?id=com.infinix.xshare', '/store/apps/details?id=com.famousringtones2017.populartones.bestringtones', '/store/apps/details?id=com.lguplus.smartotp', '/store/apps/details?id=com.lguplus.cg.legorings', '/store/apps/details?id=com.futureplay.battleground', '/store/apps/details?id=com.funplus.familyfarm', '/store/apps/details?id=me.nextdoors.fastar', '/store/apps/details?id=com.instagram.layout', '/store/apps/details?id=com.womanlog', '/store/apps/details?id=com.icreativeidea', '/store/apps/details?id=com.epicactiononline.ffxv.ane', '/store/apps/details?id=gov.match.osbp.nasa', '/s ...

# %% [markdown]
# We are now at ~1700 urls and can continue with the next step.

# %% [markdown]
# c) Access specific webpage to get description of each app and then store the description in files.

# %% [markdown]
# ### Construct Inverted file index (Vector Model)

# %% [markdown]
# d) Preprocess text using NLP techniques from __[nltk module](http://www.nltk.org/py-modindex.html)__ or spaCy.
#
# Using nltk.download(ID) to get the corpora if it is not downloaded before. __[nltk corpora](http://www.nltk.org/nltk_data/)__

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/huali50/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ...)Compute tdidf
# eg. Using functions from __[scikit-learn module](http://scikit-learn.org/stable/modules/classes.html)__. TfidfVectorizer is used for converting a collection of raw documents to a matrix of TF-IDF features.
# #### You can also build the tfidf matrix with other library or your own algorithm

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
transvector = TfidfVectorizer()
corpus = [
     'This is the first document.',
     'This is the second second document.',
     'And this is the third one.',
     'Is this the first document?',]
tfidf1 = transvector.fit_transform(corpus)
print(tfidf1.toarray())
print(transvector.get_feature_names())
# Out:
# [[0.         0.46979139 0.58028582 0.38408524 0.         0.
#   0.38408524 0.         0.38408524]
#  [0.         0.27925389 0.         0.22830836 0.         0.87501037
#   0.22830836 0.         0.22830836]
#  [0.51184851 0.         0.         0.26710379 0.51184851 0.
#   0.26710379 0.51184851 0.26710379]
#  [0.         0.46979139 0.58028582 0.38408524 0.         0.
#   0.38408524 0.         0.38408524]]
# ['and', 'document', 'first', 'is', 'one', 'second', 'the', 'third', 'this']

# %% [markdown]
# ### Query Process
#
# eg. "Dragon, Control, hero, running"
#
# eg. "The hero controls the dragon to run."
